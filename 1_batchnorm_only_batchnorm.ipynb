# %%
from tensorflow.keras.layers import Dense, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.utils import to_categorical
from matplotlib import pyplot
from tensorflow.keras import mixed_precision
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.models import Model, load_model
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
if tf.config.list_physical_devices('GPU'):
    policy = mixed_precision.Policy('mixed_float16')
    mixed_precision.set_global_policy(policy)
    batch_size = 1024
    print('Compute dtype: %s' % policy.compute_dtype)
    print('Variable dtype: %s' % policy.variable_dtype)
else:
    print('The model will run on a CPU')
    batch_size = 512
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: Tesla T4, compute capability 7.5
# Compute dtype: float16
# Variable dtype: float32

# %%
# Train without augumentation
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
numclasses = 10
inputshape = (32, 32, 3)

# %%
for i in range(9):
    pyplot.subplot(3,3,i+1)
    pyplot.tight_layout()
    pyplot.imshow(X_train[i], cmap=pyplot.get_cmap('gray'))
    pyplot.title("Label: {}".format(y_train[i]))
pyplot.show()

# %%
n_train_images = X_train.shape[0]
n_test_images = X_test.shape[0]

y_train = to_categorical(y_train, numclasses)
y_test = to_categorical(y_test, numclasses)

train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow(
        X_train,
        y=y_train,
        batch_size=batch_size)

test_generator = test_datagen.flow(
        X_test,
        y=y_test,
        batch_size=batch_size)

# %%
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=inputshape, pooling='avg')

# %%
x = base_model.output
output = Dense(numclasses, activation='softmax', dtype='float32')(x)

# %%
model = Model(inputs=base_model.input, outputs=output)

# %%
model.summary()

# %%
he_normal = tf.keras.initializers.he_normal()

# %%
for layer in model.layers:
    if layer.name.endswith('_bn'):
      new_weights = [
          he_normal(layer.weights[0].shape),
          tf.zeros(layer.weights[1].shape),
          tf.zeros(layer.weights[2].shape),
          tf.ones(layer.weights[3].shape)]

      layer.set_weights(new_weights)
      layer.trainable = True
    else:
      layer.trainable = False

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss="categorical_crossentropy", metrics=["accuracy"])

# %%
callbacks = [
    EarlyStopping(patience=20, monitor='val_accuracy', mode="auto"),
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, monitor='val_accuracy', mode='max', verbose=1),
    ModelCheckpoint('model.h5', save_best_only=True, save_weights_only=True, monitor='val_accuracy', mode='max', verbose=1)
]

# %%
results = model.fit(train_generator,
          steps_per_epoch=n_train_images // batch_size,
          validation_data=test_generator,
          validation_steps=n_test_images // batch_size,
          epochs=500,
          callbacks=callbacks)
# Out:
# Epoch 1/500
# 48/48 [==============================] - 21s 156ms/step - loss: 1.8974 - accuracy: 0.2963 - val_loss: 2.3923 - val_accuracy: 0.1008
#
# Epoch 00001: val_accuracy improved from -inf to 0.10080, saving model to model.h5
# Epoch 2/500
# 48/48 [==============================] - 6s 117ms/step - loss: 1.1928 - accuracy: 0.5737 - val_loss: 2.3917 - val_accuracy: 0.1006
#
# Epoch 00002: val_accuracy did not improve from 0.10080
# Epoch 3/500
# 48/48 [==============================] - 6s 117ms/step - loss: 1.0124 - accuracy: 0.6402 - val_loss: 2.3960 - val_accuracy: 0.0999
#
# Epoch 00003: val_accuracy did not improve from 0.10080
# Epoch 4/500
# 48/48 [==============================] - 6s 117ms/step - loss: 0.9312 - accuracy: 0.6710 - val_loss: 2.3797 - val_accuracy: 0.1011
#
# Epoch 00004: val_accuracy improved from 0.10080 to 0.10113, saving model to model.h5
# Epoch 5/500
# 48/48 [==============================] - 6s 118ms/step - loss: 0.8902 - accuracy: 0.6850 - val_loss: 2.3697 - val_accuracy: 0.1003
#
# Epoch 00005: val_accuracy did not improve from 0.10113
# Epoch 6/500
# 48/48 [==============================] - 6s 118ms/step - loss: 0.8428 - accuracy: 0.6997 - val_loss: 2.3771 - val_accuracy: 0.0987
#
# Epoch 00006: val_accuracy did not improve from 0.10113
# Epoch 7/500
# 48/48 [==============================] - 6s 118ms/step - loss: 0.8203 - accuracy: 0.7070 - val_loss: 2.4198 - val_accuracy: 0.0993
#
# Epoch 00007: val_accuracy did not improve from 0.10113
# Epoch 8/500
# 48/48 [==============================] - 6s 118ms/step - loss: 0.7872 - accuracy: 0.7240 - val_loss: 2.3933 - val_accuracy: 0.1002
#
# Epoch 00008: val_accuracy did not improve from 0.10113
# Epoch 9/500
# 48/48 [==============================] - 6s 119ms/step - loss: 0.7587 - accuracy: 0.7324 - val_loss: 2.4141 - val_accuracy: 0.1044
#
# Epoch 00009: val_accuracy improved from 0.10113 to 0.10438, saving model to model.h5
# Epoch 10/500
# 48/48 [==============================] - 6s 119ms/step - loss: 0.7517 - accuracy: 0.7351 - val_loss: 2.4132 - val_accuracy: 0.0999
#
# Epoch 00010: val_accuracy did not improve from 0.10438
# Epoch 11/500
# 48/48 [==============================] - 6s 119ms/step - loss: 0.7284 - accuracy: 0.7458 - val_loss: 2.4009 - val_accuracy: 0.1009
#
# Epoch 00011: val_accuracy did not improve from 0.10438
# Epoch 12/500
# 48/48 [==============================] - 6s 119ms/step - loss: 0.7148 - accuracy: 0.7485 - val_loss: 2.2406 - val_accuracy: 0.1214
#
# Epoch 00012: val_accuracy improved from 0.10438 to 0.12142, saving model to model.h5
# Epoch 13/500
# 48/48 [==============================] - 6s 120ms/step - loss: 0.7008 - accuracy: 0.7521 - val_loss: 1.9426 - val_accuracy: 0.1969
#
# Epoch 00013: val_accuracy improved from 0.12142 to 0.19694, saving model to model.h5
# Epoch 14/500
# 48/48 [==============================] - 6s 120ms/step - loss: 0.6850 - accuracy: 0.7589 - val_loss: 1.7161 - val_accuracy: 0.3235
#
# Epoch 00014: val_accuracy improved from 0.19694 to 0.32346, saving model to model.h5
# Epoch 15/500
# 48/48 [==============================] - 6s 120ms/step - loss: 0.6888 - accuracy: 0.7540 - val_loss: 1.3240 - val_accuracy: 0.5143
#
# Epoch 00015: val_accuracy improved from 0.32346 to 0.51432, saving model to model.h5
# Epoch 16/500
# 48/48 [==============================] - 6s 120ms/step - loss: 0.6767 - accuracy: 0.7603 - val_loss: 1.7153 - val_accuracy: 0.4733
#
# Epoch 00016: val_accuracy did not improve from 0.51432
# Epoch 17/500
# 48/48 [==============================] - 6s 120ms/step - loss: 0.6499 - accuracy: 0.7692 - val_loss: 1.7250 - val_accuracy: 0.4857
#
# Epoch 00017: val_accuracy did not improve from 0.51432
# Epoch 18/500
# 48/48 [==============================] - 6s 120ms/step - loss: 0.6430 - accuracy: 0.7735 - val_loss: 2.0544 - val_accuracy: 0.4386
#
# Epoch 00018: val_accuracy did not improve from 0.51432
# Epoch 19/500
# 48/48 [==============================] - 6s 120ms/step - loss: 0.6265 - accuracy: 0.7774 - val_loss: 2.1111 - val_accuracy: 0.4434
#
# Epoch 00019: val_accuracy did not improve from 0.51432
# Epoch 20/500
# 48/48 [==============================] - 6s 120ms/step - loss: 0.6222 - accuracy: 0.7795 - val_loss: 2.1135 - val_accuracy: 0.4439
#
# Epoch 00020: val_accuracy did not improve from 0.51432
# Epoch 21/500
# 48/48 [==============================] - 6s 120ms/step - loss: 0.6164 - accuracy: 0.7814 - val_loss: 1.7443 - val_accuracy: 0.5339
#
# Epoch 00021: val_accuracy improved from 0.51432 to 0.53385, saving model to model.h5
# Epoch 22/500
# 48/48 [==============================] - 6s 121ms/step - loss: 0.6093 - accuracy: 0.7878 - val_loss: 2.2867 - val_accuracy: 0.4271
#
# Epoch 00022: val_accuracy did not improve from 0.53385
# Epoch 23/500
# 48/48 [==============================] - 6s 121ms/step - loss: 0.6013 - accuracy: 0.7865 - val_loss: 2.0857 - val_accuracy: 0.4759
#
# Epoch 00023: val_accuracy did not improve from 0.53385
# Epoch 24/500
# 48/48 [==============================] - 6s 121ms/step - loss: 0.5911 - accuracy: 0.7911 - val_loss: 2.2252 - val_accuracy: 0.4419
#
# Epoch 00024: val_accuracy did not improve from 0.53385
# Epoch 25/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.5854 - accuracy: 0.7936 - val_loss: 1.7832 - val_accuracy: 0.4948
#
# Epoch 00025: val_accuracy did not improve from 0.53385
# Epoch 26/500
# 48/48 [==============================] - 6s 121ms/step - loss: 0.5780 - accuracy: 0.7945 - val_loss: 1.7600 - val_accuracy: 0.5102
#
# Epoch 00026: val_accuracy did not improve from 0.53385
# Epoch 27/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.5624 - accuracy: 0.8035 - val_loss: 2.0977 - val_accuracy: 0.4782
#
# Epoch 00027: val_accuracy did not improve from 0.53385
# Epoch 28/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.5553 - accuracy: 0.8041 - val_loss: 1.9198 - val_accuracy: 0.4961
#
# Epoch 00028: val_accuracy did not improve from 0.53385
# Epoch 29/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.5440 - accuracy: 0.8090 - val_loss: 1.6529 - val_accuracy: 0.5417
#
# Epoch 00029: val_accuracy improved from 0.53385 to 0.54167, saving model to model.h5
# Epoch 30/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.5422 - accuracy: 0.8086 - val_loss: 2.0243 - val_accuracy: 0.5122
#
# Epoch 00030: val_accuracy did not improve from 0.54167
# Epoch 31/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.5355 - accuracy: 0.8101 - val_loss: 1.8219 - val_accuracy: 0.5136
#
# Epoch 00031: val_accuracy did not improve from 0.54167
# Epoch 32/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.5326 - accuracy: 0.8079 - val_loss: 2.2078 - val_accuracy: 0.4743
#
# Epoch 00032: val_accuracy did not improve from 0.54167
# Epoch 33/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.5195 - accuracy: 0.8159 - val_loss: 1.9500 - val_accuracy: 0.5241
#
# Epoch 00033: val_accuracy did not improve from 0.54167
# Epoch 34/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.5233 - accuracy: 0.8135 - val_loss: 2.0802 - val_accuracy: 0.4937
#
# Epoch 00034: val_accuracy did not improve from 0.54167
# Epoch 35/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.5200 - accuracy: 0.8160 - val_loss: 1.6210 - val_accuracy: 0.5571
#
# Epoch 00035: val_accuracy improved from 0.54167 to 0.55707, saving model to model.h5
# Epoch 36/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.5091 - accuracy: 0.8185 - val_loss: 1.5079 - val_accuracy: 0.5789
#
# Epoch 00036: val_accuracy improved from 0.55707 to 0.57888, saving model to model.h5
# Epoch 37/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.4923 - accuracy: 0.8274 - val_loss: 1.5539 - val_accuracy: 0.5889
#
# Epoch 00037: val_accuracy improved from 0.57888 to 0.58887, saving model to model.h5
# Epoch 38/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.4844 - accuracy: 0.8299 - val_loss: 1.9044 - val_accuracy: 0.5412
#
# Epoch 00038: val_accuracy did not improve from 0.58887
# Epoch 39/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.4839 - accuracy: 0.8293 - val_loss: 1.9918 - val_accuracy: 0.5222
#
# Epoch 00039: val_accuracy did not improve from 0.58887
# Epoch 40/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.4891 - accuracy: 0.8264 - val_loss: 2.0132 - val_accuracy: 0.5039
#
# Epoch 00040: val_accuracy did not improve from 0.58887
# Epoch 41/500
# 48/48 [==============================] - 6s 121ms/step - loss: 0.4792 - accuracy: 0.8313 - val_loss: 2.2015 - val_accuracy: 0.5004
#
# Epoch 00041: val_accuracy did not improve from 0.58887
# Epoch 42/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.4788 - accuracy: 0.8307 - val_loss: 1.3493 - val_accuracy: 0.6224
#
# Epoch 00042: val_accuracy improved from 0.58887 to 0.62240, saving model to model.h5
# Epoch 43/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.4640 - accuracy: 0.8344 - val_loss: 1.7775 - val_accuracy: 0.5545
#
# Epoch 00043: val_accuracy did not improve from 0.62240
# Epoch 44/500
# 48/48 [==============================] - 6s 121ms/step - loss: 0.4681 - accuracy: 0.8340 - val_loss: 1.9092 - val_accuracy: 0.5365
#
# Epoch 00044: val_accuracy did not improve from 0.62240
# Epoch 45/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.4541 - accuracy: 0.8388 - val_loss: 1.4619 - val_accuracy: 0.6179
#
# Epoch 00045: val_accuracy did not improve from 0.62240
# Epoch 46/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.4493 - accuracy: 0.8401 - val_loss: 1.5689 - val_accuracy: 0.5846
#
# Epoch 00046: val_accuracy did not improve from 0.62240
# Epoch 47/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.4463 - accuracy: 0.8424 - val_loss: 2.0425 - val_accuracy: 0.5232
#
# Epoch 00047: val_accuracy did not improve from 0.62240
# Epoch 48/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.4404 - accuracy: 0.8441 - val_loss: 1.5173 - val_accuracy: 0.5939
#
# Epoch 00048: val_accuracy did not improve from 0.62240
# Epoch 49/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.4455 - accuracy: 0.8403 - val_loss: 1.6694 - val_accuracy: 0.5894
#
# Epoch 00049: val_accuracy did not improve from 0.62240
# Epoch 50/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.4411 - accuracy: 0.8422 - val_loss: 1.5799 - val_accuracy: 0.6019
#
# Epoch 00050: val_accuracy did not improve from 0.62240
# Epoch 51/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.4265 - accuracy: 0.8499 - val_loss: 1.3552 - val_accuracy: 0.6438
#
# Epoch 00051: val_accuracy improved from 0.62240 to 0.64377, saving model to model.h5
# Epoch 52/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.4305 - accuracy: 0.8474 - val_loss: 1.3806 - val_accuracy: 0.6318
#
# Epoch 00052: val_accuracy did not improve from 0.64377
# Epoch 53/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.4184 - accuracy: 0.8497 - val_loss: 1.5377 - val_accuracy: 0.6088
#
# Epoch 00053: val_accuracy did not improve from 0.64377
# Epoch 54/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.4171 - accuracy: 0.8537 - val_loss: 1.7362 - val_accuracy: 0.5839
#
# Epoch 00054: val_accuracy did not improve from 0.64377
# Epoch 55/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.4182 - accuracy: 0.8517 - val_loss: 2.0096 - val_accuracy: 0.5523
#
# Epoch 00055: val_accuracy did not improve from 0.64377
# Epoch 56/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.3961 - accuracy: 0.8602 - val_loss: 1.6272 - val_accuracy: 0.6074
#
# Epoch 00056: val_accuracy did not improve from 0.64377
# Epoch 57/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.3951 - accuracy: 0.8582 - val_loss: 1.6073 - val_accuracy: 0.6070
#
# Epoch 00057: val_accuracy did not improve from 0.64377
# Epoch 58/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.3986 - accuracy: 0.8583 - val_loss: 1.3841 - val_accuracy: 0.6267
#
# Epoch 00058: val_accuracy did not improve from 0.64377
# Epoch 59/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.3952 - accuracy: 0.8597 - val_loss: 1.5787 - val_accuracy: 0.6083
#
# Epoch 00059: val_accuracy did not improve from 0.64377
# Epoch 60/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.3889 - accuracy: 0.8617 - val_loss: 1.4957 - val_accuracy: 0.6108
#
# Epoch 00060: val_accuracy did not improve from 0.64377
# Epoch 61/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.3890 - accuracy: 0.8595 - val_loss: 2.1721 - val_accuracy: 0.5279
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
#
# Epoch 00061: val_accuracy did not improve from 0.64377
# Epoch 62/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.3349 - accuracy: 0.8840 - val_loss: 1.3514 - val_accuracy: 0.6513
#
# Epoch 00062: val_accuracy improved from 0.64377 to 0.65126, saving model to model.h5
# Epoch 63/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.2773 - accuracy: 0.9109 - val_loss: 1.1785 - val_accuracy: 0.6811
#
# Epoch 00063: val_accuracy improved from 0.65126 to 0.68110, saving model to model.h5
# Epoch 64/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.2549 - accuracy: 0.9203 - val_loss: 1.1132 - val_accuracy: 0.6933
#
# Epoch 00064: val_accuracy improved from 0.68110 to 0.69325, saving model to model.h5
# Epoch 65/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.2498 - accuracy: 0.9234 - val_loss: 1.0985 - val_accuracy: 0.6965
#
# Epoch 00065: val_accuracy improved from 0.69325 to 0.69651, saving model to model.h5
# Epoch 66/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.2340 - accuracy: 0.9307 - val_loss: 1.1036 - val_accuracy: 0.6998
#
# Epoch 00066: val_accuracy improved from 0.69651 to 0.69976, saving model to model.h5
# Epoch 67/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.2292 - accuracy: 0.9328 - val_loss: 1.1018 - val_accuracy: 0.6967
#
# Epoch 00067: val_accuracy did not improve from 0.69976
# Epoch 68/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.2188 - accuracy: 0.9355 - val_loss: 1.0982 - val_accuracy: 0.6978
#
# Epoch 00068: val_accuracy did not improve from 0.69976
# Epoch 69/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.2166 - accuracy: 0.9368 - val_loss: 1.1156 - val_accuracy: 0.6966
#
# Epoch 00069: val_accuracy did not improve from 0.69976
# Epoch 70/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.2130 - accuracy: 0.9383 - val_loss: 1.1324 - val_accuracy: 0.6946
#
# Epoch 00070: val_accuracy did not improve from 0.69976
# Epoch 71/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.2090 - accuracy: 0.9390 - val_loss: 1.1470 - val_accuracy: 0.6933
#
# Epoch 00071: val_accuracy did not improve from 0.69976
# Epoch 72/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.2022 - accuracy: 0.9424 - val_loss: 1.1497 - val_accuracy: 0.6937
#
# Epoch 00072: val_accuracy did not improve from 0.69976
# Epoch 73/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.2040 - accuracy: 0.9420 - val_loss: 1.1571 - val_accuracy: 0.6950
#
# Epoch 00073: val_accuracy did not improve from 0.69976
# Epoch 74/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.1957 - accuracy: 0.9437 - val_loss: 1.1707 - val_accuracy: 0.6937
#
# Epoch 00074: val_accuracy did not improve from 0.69976
# Epoch 75/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.1931 - accuracy: 0.9451 - val_loss: 1.1691 - val_accuracy: 0.6946
#
# Epoch 00075: val_accuracy did not improve from 0.69976
# Epoch 76/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.1897 - accuracy: 0.9475 - val_loss: 1.1965 - val_accuracy: 0.6890
#
# Epoch 00076: ReduceLROnPlateau reducing learning rate to 9.999999310821295e-05.
#
# Epoch 00076: val_accuracy did not improve from 0.69976
# Epoch 77/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.1838 - accuracy: 0.9506 - val_loss: 1.1939 - val_accuracy: 0.6892
#
# Epoch 00077: val_accuracy did not improve from 0.69976
# Epoch 78/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.1833 - accuracy: 0.9505 - val_loss: 1.1858 - val_accuracy: 0.6943
#
# Epoch 00078: val_accuracy did not improve from 0.69976
# Epoch 79/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.1810 - accuracy: 0.9521 - val_loss: 1.1820 - val_accuracy: 0.6947
#
# Epoch 00079: val_accuracy did not improve from 0.69976
# Epoch 80/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.1789 - accuracy: 0.9522 - val_loss: 1.1963 - val_accuracy: 0.6923
#
# Epoch 00080: val_accuracy did not improve from 0.69976
# Epoch 81/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.1784 - accuracy: 0.9537 - val_loss: 1.1825 - val_accuracy: 0.6955
#
# Epoch 00081: val_accuracy did not improve from 0.69976
# Epoch 82/500
# 48/48 [==============================] - 6s 123ms/step - loss: 0.1755 - accuracy: 0.9528 - val_loss: 1.1858 - val_accuracy: 0.6933
#
# Epoch 00082: val_accuracy did not improve from 0.69976
# Epoch 83/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.1796 - accuracy: 0.9520 - val_loss: 1.1956 - val_accuracy: 0.6921
#
# Epoch 00083: val_accuracy did not improve from 0.69976
# Epoch 84/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.1793 - accuracy: 0.9518 - val_loss: 1.1919 - val_accuracy: 0.6931
#
# Epoch 00084: val_accuracy did not improve from 0.69976
# Epoch 85/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.1769 - accuracy: 0.9518 - val_loss: 1.1824 - val_accuracy: 0.6946
#
# Epoch 00085: val_accuracy did not improve from 0.69976
# Epoch 86/500
# 48/48 [==============================] - 6s 122ms/step - loss: 0.1793 - accuracy: 0.9502 - val_loss: 1.1982 - val_accuracy: 0.6935
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00086: val_accuracy did not improve from 0.69976

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["accuracy"], label="accuracy")
plt.plot(results.history["val_accuracy"], label="val_accuracy")
plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_accuracy")
plt.legend();

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();
